# %%
word_freqs = {
    "たのしい": 6,
    "たのしさ": 2,
    "うつくしい": 4,
    "うつくしさ": 1,
}

vocab = sorted(set([char for word in word_freqs for char in word]))
print(vocab)
splits = {word: [char for char in word] for word in word_freqs}
print(splits)
# Out:
# ['い', 'う', 'く', 'さ', 'し', 'た', 'つ', 'の']
# {'たのしい': ['た', 'の', 'し', 'い'], 'たのしさ': ['た', 'の', 'し', 'さ'], 'うつくしい': ['う', 'つ', 'く', 'し', 'い'], 'うつくしさ': ['う', 'つ', 'く', 'し', 'さ']}

# %%
from collections import Counter

def compute_most_frequent_pair(
    splits: dict[str, list[str]]
) -> tuple[str, str]:
    """
    最も頻度の高い隣接するサブワードの組を計算する
    """
    pair_freqs = Counter()  # サブワード組のカウンタ
    for word, freq in word_freqs.items():  # すべての単語を処理
        split = splits[word]  # 現在の単語の分割状態を取得
        # すべての隣接したサブワードの組を処理
        for i in range(len(split)-1):
            pair = (split[i], split[i+1])
            # サブワードの組の頻度にを加算
            pair_freqs[pair] += freq
    
    # カウンタから最も頻度の高いサブワードの組を取得
    pair, _ = pair_freqs.most_common(1)[0]
    return pair


def merge_pair(
    target_pair: tuple[str, str],
    splits: dict[str, list[str]]
) -> dict[str, list[str]]:
    """
    サブワードの組を結合する
    """
    l_str, r_str = target_pair
    for word in word_freqs:  # すべての単語を処理
        split = splits[word]  # 現在の単語の分割状態を取得
        i = 0
        # すべての隣接したサブワードの組を処理
        while i < len(split) - 1:
            # サブワードの組が結合対象と一致したら結合
            if split[i] == l_str and split[i+1] == r_str:
                split = split[:i] + [l_str + r_str] + split[i+2:]
            i += 1
        splits[word] = split  # 現在の結合状態を更新
    return splits

# %%
for step in range(9):
    # 最も頻度の高い隣接するサブワードの組を計算
    target_pair = compute_most_frequent_pair(splits)
    print(f"target_pair: {target_pair}")

    # サブワードの組を結合
    splits = merge_pair(target_pair, splits)
    print(f"splits: {splits}")

    # 語彙にサブワードの組を追加
    vocab.append(str(target_pair))
# Out:
# target_pair: ('し', 'い')
# splits: {'たのしい': ['た', 'の', 'しい'], 'たのしさ': ['た', 'の', 'し', 'さ'], 'うつくしい': ['う', 'つ', 'く', 'しい'], 'うつくしさ': ['う', 'つ', 'く', 'し', 'さ']}
# target_pair: ('た', 'の')
# splits: {'たのしい': ['たの', 'しい'], 'たのしさ': ['たの', 'し', 'さ'], 'うつくしい': ['う', 'つ', 'く', 'しい'], 'うつくしさ': ['う', 'つ', 'く', 'し', 'さ']}
# target_pair: ('たの', 'しい')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たの', 'し', 'さ'], 'うつくしい': ['う', 'つ', 'く', 'しい'], 'うつくしさ': ['う', 'つ', 'く', 'し', 'さ']}
# target_pair: ('う', 'つ')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たの', 'し', 'さ'], 'うつくしい': ['うつ', 'く', 'しい'], 'うつくしさ': ['うつ', 'く', 'し', 'さ']}
# target_pair: ('うつ', 'く')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たの', 'し', 'さ'], 'うつくしい': ['うつく', 'しい'], 'うつくしさ': ['うつく', 'し', 'さ']}
# target_pair: ('うつく', 'しい')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たの', 'し', 'さ'], 'うつくしい': ['うつくしい'], 'うつくしさ': ['うつく', 'し', 'さ']}
# target_pair: ('し', 'さ')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たの', 'しさ'], 'うつくしい': ['うつくしい'], 'うつくしさ': ['うつく', 'しさ']}
# target_pair: ('たの', 'しさ')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たのしさ'], 'うつくしい': ['うつくしい'], 'うつくしさ': ['うつく', 'しさ']}
# target_pair: ('うつく', 'しさ')
# splits: {'たのしい': ['たのしい'], 'たのしさ': ['たのしさ'], 'うつくしい': ['うつくしい'], 'うつくしさ': ['うつくしさ']}

# %%
print(vocab)
# Out:
# ['い', 'う', 'く', 'さ', 'し', 'た', 'つ', 'の', "('し', 'い')", "('た', 'の')", "('たの', 'しい')", "('う', 'つ')", "('うつ', 'く')", "('うつく', 'しい')", "('し', 'さ')", "('たの', 'しさ')", "('うつく', 'しさ')"]

# %%
# %pip install transformers[ja,sentencepiece,torch]==4.36
# Out:
# Requirement already satisfied: transformers==4.36 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (4.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2.32.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (4.67.3)
# Requirement already satisfied: fugashi>=1.0 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.5.2)
# Requirement already satisfied: ipadic<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.0.0)
# Requirement already satisfied: unidic-lite>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.0.8)
# Requirement already satisfied: unidic>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.1.0)
# Requirement already satisfied: sudachipy>=0.6.6 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (0.6.11)
# Requirement already satisfied: sudachidict-core>=20220729 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (20260116)
# Requirement already satisfied: rhoknp<1.3.1,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.3.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (5.29.6)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (2.10.0+cpu)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from transformers[ja,sentencepiece,torch]==4.36) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.21.0->transformers[ja,sentencepiece,torch]==4.36) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (3.1.6)
# Requirement already satisfied: wasabi<1.0.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from unidic>=1.0.2->transformers[ja,sentencepiece,torch]==4.36) (0.10.1)
# Requirement already satisfied: plac<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from unidic>=1.0.2->transformers[ja,sentencepiece,torch]==4.36) (1.4.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.36->transformers[ja,sentencepiece,torch]==4.36) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[ja,sentencepiece,torch]==4.36) (3.0.3)

# %%
from transformers import AutoTokenizer

mbert_tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-multilingual-cased"
)
print(mbert_tokenizer.tokenize("スターバックス"))
# Out:
# ['ス', '##ター', '##バ', '##ックス']

# %%
sample_text = "スターバックスでコーヒーを飲みながら勉強中"
print(mbert_tokenizer.tokenize(sample_text))
# Out:
# ['ス', '##ター', '##バ', '##ックス', '##で', '##コ', '##ー', '##ヒ', '##ー', '##を', '飲', 'み', '##ながら', '勉', '強', '中']

# %%
xlmr_tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
print(xlmr_tokenizer.tokenize(sample_text))
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['▁', 'スター', 'バック', 'ス', 'で', 'コーヒー', 'を', '飲み', 'ながら', '勉強', '中']

# %%
print(xlmr_tokenizer.tokenize("こんにちは、本日はよろしくお願いします"))
# Out:
# ['▁', 'こんにちは', '、', '本', '日は', 'よろしくお願いします']

# %%
bert_ja_tokenizer = AutoTokenizer.from_pretrained(
    "cl-tohoku/bert-base-japanese-v3"
)
print(bert_ja_tokenizer.tokenize(sample_text))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ['スター', '##バック', '##ス', 'で', 'コーヒー', 'を', '飲み', 'ながら', '勉強', '中']

# %%
print(bert_ja_tokenizer.tokenize("私は日本で生まれました"))
# Out:
# ['私', 'は', '日本', 'で', '生まれ', 'まし', 'た']
