# %%
# %pip install transformers[ja,sentencepiece,torch]==4.30 pandas
# Out:
# ...
#   Using cached transformers-4.30.0-py3-none-any.whl.metadata (113 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# ...
# Using cached transformers-4.30.0-py3-none-any.whl (7.2 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ...

# %%
from transformers import pipeline

# %%
generater = pipeline(
    "text-generation", 
    model = "abeja/gpt2-large-japanese"
)
# "日本で一番高い山は"に続くテキストを生成
outputs = generater("日本で一番高い山は")
print(outputs[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/437 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie transformer.wte.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# GPT2LMHeadModel LOAD REPORT from: abeja/gpt2-large-japanese
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...35}.attn.bias        | UNEXPECTED |  |
# transformer.h.{0...35}.attn.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %%
import pandas as pd

fill_mask = pipeline(
    "fill-mask",
    model = "cl-tohoku/bert-base-japanese-v3"
)
masked_text = "日本の首都は[MASK] である"
outputs = fill_mask(masked_text)
display(pd.DataFrame(outputs[:3]))

# %%
masked_text = "今日の映画は刺激的で楽しかった。この映画は [MASK] 。"
outputs = fill_mask(masked_text)
display(pd.DataFrame(outputs[:3]))

# %%
t2t_generater = pipeline(
    "text2text-generation",
    model = "retrieva-jp/t5-large-long"
)
masked_text = "江戸幕府を開いたのは、<extra_id_0> である"
outputs = t2t_generater(masked_text, eos_token_id=32098)
print(outputs[0]["generated_text"])

# %%
"日本銀行" in t2t_generater.tokenizer.vocab
